# %%
import pandas as pd

project = pd.read_csv('/content/data_orders.csv')

# %%
project
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 1           20:57:32         -0.950385        51.456843          NaN
# 2           12:07:50         -0.969520        51.455544        477.0
# 3           13:50:20         -1.054671        51.460544        658.0
# 4           21:24:45         -0.967605        51.458236          NaN
# ...              ...               ...              ...          ...
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# ...

# %%
project.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds
# 0                          198.0
# 1                          128.0
# 2                           46.0
# 3                           62.0
# 4                            NaN

# %%
project.tail()
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 10711  3000599186906                 4                       0
# 10712  3000599186962                 4                       0
# 10713  3000599187034                 4                       1
# 10714  3000599187024                 4                       0
# 10715  3000592871241                 4                       1
#
#        cancellations_time_in_seconds
# 10711                           36.0
# 10712                            4.0
# 10713                           34.0
# ...

# %%
project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10716 entries, 0 to 10715
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_datetime                 10716 non-null  object
#  1   origin_longitude               10716 non-null  float64
#  2   origin_latitude                10716 non-null  float64
#  3   m_order_eta                    2814 non-null   float64
#  4   order_gk                       10716 non-null  int64
#  5   order_status_key               10716 non-null  int64
#  6   is_driver_assigned_key         10716 non-null  int64
#  7   cancellations_time_in_seconds  7307 non-null   float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 669.9+ KB

# %%
project.describe()
# Out:
#        origin_longitude  origin_latitude  m_order_eta      order_gk  \
# count      10716.000000     10716.000000  2814.000000  1.071600e+04
# mean          -0.964323        51.450541   441.415423  3.000598e+12
# std            0.022818         0.011984   288.006379  2.396261e+07
# min           -1.066957        51.399323    60.000000  3.000550e+12
# 25%           -0.974363        51.444643   233.000000  3.000583e+12
# 50%           -0.966386        51.451972   368.500000  3.000595e+12
# 75%           -0.949605        51.456725   653.000000  3.000623e+12
# max           -0.867088        51.496169  1559.000000  3.000633e+12
#
#        order_status_key  is_driver_assigned_key  cancellations_time_in_seconds
# count      10716.000000            10716.000000                    7307.000000
# mean           5.590612                0.262598                     157.892021
# std            2.328845                0.440066                     213.366963
# ...

# %%
project.shape
# Out:
# (10716, 8)

# %%
project.size
# Out:
# 85728

# %%
project.columns
# Out:
# Index(['order_datetime', 'origin_longitude', 'origin_latitude', 'm_order_eta',
#        'order_gk', 'order_status_key', 'is_driver_assigned_key',
#        'cancellations_time_in_seconds'],
#       dtype='object')

# %%
project.dtypes
# Out:
# order_datetime                    object
# origin_longitude                 float64
# origin_latitude                  float64
# m_order_eta                      float64
# order_gk                           int64
# order_status_key                   int64
# is_driver_assigned_key             int64
# cancellations_time_in_seconds    float64
# dtype: object

# %%
project.tail(10)
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 10706       13:14:50         -0.975372        51.457846          NaN
# 10707       13:10:07         -0.976266        51.459108          NaN
# 10708       12:45:23         -0.975372        51.457846          NaN
# 10709       12:44:11         -0.975372        51.457846          NaN
# 10710       12:42:52         -0.975372        51.457846          NaN
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 10706  3000599186984                 4                       0
# 10707  3000599186803                 4                       0
# ...

# %%
project.sample(10)
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 10252       23:27:34         -0.982640        51.464204          NaN
# 7947        23:33:51         -0.958159        51.460102          NaN
# 1473        18:54:29         -0.950543        51.449688          NaN
# 5903        08:52:26         -0.968562        51.430686          NaN
# 5743        00:11:55         -0.979391        51.450742        239.0
# 2515        22:03:08         -0.966536        51.454712          NaN
# 1655        21:00:56         -0.936913        51.449564          NaN
# 1574        23:47:51         -0.943582        51.439767          NaN
# 666         21:12:57         -0.973369        51.453935          NaN
# 8560        17:29:46         -0.932760        51.440734          NaN
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 10252  3000590781020                 4                       0
# 7947   3000617551631                 4                       0
# ...

# %%
project.sample(10,random_state=34)
# Out:
#      order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 8959       08:43:20         -0.986445        51.445740          NaN
# 7900       22:44:17         -0.950865        51.449670          NaN
# 7145       01:14:37         -1.034398        51.456567          NaN
# 8086       22:09:09         -0.902101        51.458205        239.0
# 6629       22:39:48         -0.976677        51.446739          NaN
# 9827       04:24:19         -0.979589        51.423967          NaN
# 8761       09:34:21         -0.963441        51.452126          NaN
# 387        16:11:27         -0.979302        51.471700          NaN
# 2599       09:38:39         -0.949547        51.447772          NaN
# 2399       16:31:05         -0.971592        51.445218          NaN
#
#            order_gk  order_status_key  is_driver_assigned_key  \
# 8959  3000557786906                 9                       0
# 7900  3000617527149                 4                       0
# ...

# %%
filter = project['origin_longitude']
print(filter)
print(type(filter))
# Out:
# 0       -0.978916
# 1       -0.950385
# 2       -0.969520
# 3       -1.054671
# 4       -0.967605
#            ...
# 10711   -0.975372
# 10712   -0.975372
# 10713   -0.972926
# 10714   -0.975372
# 10715   -0.974738
# Name: origin_longitude, Length: 10716, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
filter = project[['origin_longitude']]
print(filter)
print(type(filter))
# Out:
#        origin_longitude
# 0             -0.978916
# 1             -0.950385
# 2             -0.969520
# 3             -1.054671
# 4             -0.967605
# ...                 ...
# 10711         -0.975372
# 10712         -0.975372
# 10713         -0.972926
# 10714         -0.975372
# 10715         -0.974738
#
# [10716 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
filter = project[['order_status_key','origin_longitude']]
print(filter)
print(type(filter))
# Out:
#        order_status_key  origin_longitude
# 0                     4         -0.978916
# 1                     4         -0.950385
# 2                     4         -0.969520
# 3                     4         -1.054671
# 4                     9         -0.967605
# ...                 ...               ...
# 10711                 4         -0.975372
# 10712                 4         -0.975372
# 10713                 4         -0.972926
# 10714                 4         -0.975372
# 10715                 4         -0.974738
#
# [10716 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
project
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 1           20:57:32         -0.950385        51.456843          NaN
# 2           12:07:50         -0.969520        51.455544        477.0
# 3           13:50:20         -1.054671        51.460544        658.0
# 4           21:24:45         -0.967605        51.458236          NaN
# ...              ...               ...              ...          ...
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# ...

# %%
project.iloc[0]
# Out:
# order_datetime                        18:08:07
# origin_longitude                     -0.978916
# origin_latitude                      51.456173
# m_order_eta                               60.0
# order_gk                         3000583041974
# order_status_key                             4
# is_driver_assigned_key                       1
# cancellations_time_in_seconds            198.0
# Name: 0, dtype: object

# %%
project.iloc[0:5]  #slicing
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds
# 0                          198.0
# 1                          128.0
# 2                           46.0
# 3                           62.0
# 4                            NaN

# %%
project.loc[0:5]
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
# 5       21:21:23         -0.947011        51.456380          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
# 5  3000583117054                 9                       0
#
#    cancellations_time_in_seconds
# 0                          198.0
# ...

# %%
project.iloc[6:12:1]
# Out:
#    order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 6        07:58:15         -0.955637        51.470372          NaN
# 7        07:53:46         -0.978230        51.454575          NaN
# 8        08:53:01         -1.052298        51.454308          NaN
# 9        06:33:52         -0.976216        51.433202          NaN
# 10       15:40:15         -0.934670        51.447065          NaN
# 11       20:59:35         -0.972735        51.452489          NaN
#
#          order_gk  order_status_key  is_driver_assigned_key  \
# 6   3000582791789                 9                       0
# 7   3000582791562                 9                       0
# 8   3000582817606                 9                       0
# 9   3000582765616                 4                       0
# 10  3000582991062                 4                       0
# 11  3000583116472                 4                       0
#
#     cancellations_time_in_seconds
# 6                             NaN
# ...

# %%
project.iloc[6:12,1:3]
# Out:
#     origin_longitude  origin_latitude
# 6          -0.955637        51.470372
# 7          -0.978230        51.454575
# 8          -1.052298        51.454308
# 9          -0.976216        51.433202
# 10         -0.934670        51.447065
# 11         -0.972735        51.452489

# %%
project.loc[6:12,['origin_latitude','order_gk']]
# Out:
#     origin_latitude       order_gk
# 6         51.470372  3000582791789
# 7         51.454575  3000582791562
# 8         51.454308  3000582817606
# 9         51.433202  3000582765616
# 10        51.447065  3000582991062
# 11        51.452489  3000583116472
# 12        51.459481  3000582765488

# %%
project.loc[6:12,'origin_latitude' : 'order_gk' ]
# Out:
#     origin_latitude  m_order_eta       order_gk
# 6         51.470372          NaN  3000582791789
# 7         51.454575          NaN  3000582791562
# 8         51.454308          NaN  3000582817606
# 9         51.433202          NaN  3000582765616
# 10        51.447065          NaN  3000582991062
# 11        51.452489          NaN  3000583116472
# 12        51.459481          NaN  3000582765488

# %%
project1 = pd.read_csv('/content/data_offers.csv')
project1
# Out:
#              order_gk      offer_id
# 0       3000579625629  300050936206
# 1       3000627306450  300052064651
# 2       3000632920686  300052408812
# 3       3000632771725  300052393030
# 4       3000583467642  300051001196
# ...               ...           ...
# 334358  3000552921666  300050611632
# 334359  3000593796526  300051443024
# 334360  3000590955748  300051340498
# 334361  3000557510943  300050772593
# 334362  3000630405861  300052291934
#
# [334363 rows x 2 columns]

# %%
project1.head()
# Out:
#         order_gk      offer_id
# 0  3000579625629  300050936206
# 1  3000627306450  300052064651
# 2  3000632920686  300052408812
# 3  3000632771725  300052393030
# 4  3000583467642  300051001196

# %%
df = project.merge(right=project1,how='inner',on='order_gk')
df
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 1           20:57:32         -0.950385        51.456843          NaN
# 2           20:57:32         -0.950385        51.456843          NaN
# 3           20:57:32         -0.950385        51.456843          NaN
# 4           12:07:50         -0.969520        51.455544        477.0
# ...              ...               ...              ...          ...
# 31263       12:44:11         -0.975372        51.457846          NaN
# 31264       12:42:52         -0.975372        51.457846          NaN
# 31265       13:11:35         -0.975372        51.457846          NaN
# 31266       13:17:21         -0.972926        51.457693         60.0
# 31267       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# ...

# %%
import numpy as np
yes_no = np.where(df['is_driver_assigned_key']==1,'yes','no')

# %%
df['is_driver_assigned'] = yes_no
df['is_driver_assigned']
# Out:
# 0        yes
# 1         no
# 2         no
# 3         no
# 4        yes
#         ...
# 31263     no
# 31264     no
# 31265     no
# 31266    yes
# 31267    yes
# Name: is_driver_assigned, Length: 31268, dtype: object

# %%
status = np.where(df['order_status_key']==4,'client_cancel','System_cancel')

# %%
df['status_right'] = status
df['status_right']
# Out:
# 0        client_cancel
# 1        client_cancel
# 2        client_cancel
# 3        client_cancel
# 4        client_cancel
#              ...
# 31263    client_cancel
# 31264    client_cancel
# 31265    client_cancel
# 31266    client_cancel
# 31267    client_cancel
# Name: status_right, Length: 31268, dtype: object

# %%
df.drop(columns=['is_driver_assigned_key','order_status_key'],inplace=True)

# %%
df = df.rename(columns={"order_datetime":"order_TIme"})

# %%
df.sample(n=10, random_state=42)
# Out:
#       order_TIme  origin_longitude  origin_latitude  m_order_eta  \
# 30194   21:15:35         -0.969588        51.455780        299.0
# 14748   10:13:35         -0.955958        51.430362          NaN
# 29083   09:16:38         -1.033560        51.441967          NaN
# 16926   02:08:09         -0.967676        51.444489          NaN
# 21530   21:44:21         -0.972683        51.456762          NaN
# 13008   03:03:45         -0.966745        51.453236          NaN
# 2034    14:41:22         -0.948642        51.449587          NaN
# 2229    20:54:03         -0.991382        51.476339          NaN
# 16632   18:06:17         -0.948907        51.444643          NaN
# 18189   07:52:29         -0.973793        51.458665        479.0
#
#             order_gk  cancellations_time_in_seconds      offer_id  \
# 30194  3000555697076                          223.0  300050725946
# 14748  3000626091676                           91.0  300052014519
# ...

# %%
df.groupby(['status_right'])['order_gk'].count()
# Out:
# status_right
# System_cancel     9473
# client_cancel    21795
# Name: order_gk, dtype: int64

# %%
df.groupby(['is_driver_assigned' , 'status_right'])['order_gk'].count()
# Out:
# is_driver_assigned  status_right
# no                  System_cancel     9469
#                     client_cancel    13435
# yes                 System_cancel        4
#                     client_cancel     8360
# Name: order_gk, dtype: int64

# %%
df_q1=df.pivot_table(columns=['is_driver_assigned','status_right'],values ='order_gk',aggfunc='count')

# %%
# df_q1 =  df.groupby(['is_driver_assigned', 'status_right'])['order_gk'].count()
df_q1.plot(kind='bar',subplots=False, figsize=(7, 7), legend=True)
# Out:
# <Axes: >

# %%
project['order_datetime'].apply(lambda x: str(x).split(':')[0])
# Out:
# 0        18
# 1        20
# 2        12
# 3        13
# 4        21
#          ..
# 10711    13
# 10712    13
# 10713    13
# 10714    13
# 10715    11
# Name: order_datetime, Length: 10716, dtype: object

# %%
df['order_hours'] = project['order_datetime'].apply(lambda x: str(x).split(':')[0])
df[['order_gk','order_hours']].head()
# Out:
#         order_gk order_hours
# 0  3000583041974          18
# 1  3000583116437          20
# 2  3000583116437          12
# 3  3000583116437          13
# 4  3000582891479          21

# %%
df_hours = df.groupby(['order_hours'])['order_gk'].count()
df_hours
# Out:
# order_hours
# 00     683
# 01     471
# 02     555
# 03     513
# 04     152
# 05      67
# 06     159
# 07     447
# 08    1082
# 09     412
# 10     170
# 11     193
# 12     256
# 13     366
# 14     256
# 15     439
# 16     356
# 17     541
# 18     414
# 19     317
# 20     469
# 21     846
# 22     716
# 23     836
# Name: order_gk, dtype: int64

# %%
df_hours.plot()
# Out:
# <Axes: xlabel='order_hours'>

# %%
df_hours.plot(xticks=range(0,24))
# Out:
# <Axes: xlabel='order_hours'>

# %%
df_hr = df.groupby(['order_hours','status_right'])['order_gk'].count()
df_hr.head()
# Out:
# order_hours  status_right
# 00           System_cancel    200
#              client_cancel    483
# 01           System_cancel    128
#              client_cancel    343
# 02           System_cancel    155
# Name: order_gk, dtype: int64

# %%
df_hr_nor = df_hr.reset_index()
df_hr_nor.head()
# Out:
#   order_hours   status_right  order_gk
# 0          00  System_cancel       200
# 1          00  client_cancel       483
# 2          01  System_cancel       128
# 3          01  client_cancel       343
# 4          02  System_cancel       155

# %%
df_q2_pivot = df_hr_nor.pivot(index='order_hours',columns='status_right',values='order_gk')
df_q2_pivot.head()
# Out:
# status_right  System_cancel  client_cancel
# order_hours
# 00                      200            483
# 01                      128            343
# 02                      155            400
# 03                      145            368
# 04                       44            108

# %%
df_q2_pivot.plot(xticks=range(0,24))
# Out:
# <Axes: xlabel='order_hours'>

# %%
df_q3 = df.groupby(by=['order_hours', 'is_driver_assigned'])['cancellations_time_in_seconds'].count()
df_q3 = df_q3.reset_index()
df_q3 = df_q3.pivot(index='order_hours', columns='is_driver_assigned', values='cancellations_time_in_seconds')
df_q3.head()
# Out:
# is_driver_assigned   no  yes
# order_hours
# 00                  302  181
# 01                  208  135
# 02                  261  139
# 03                  230  138
# 04                   68   40

# %%
df_q3.plot(xticks=range(0,24),figsize=(13,5))
# Out:
# <Axes: xlabel='order_hours'>

# %%
import folium

m = folium.Map(location=[31.55, 74.55], zoom_start=10, width='100%', height='100%')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map([df['origin_latitude'].mean(),df['origin_longitude'].mean()],zoom_start=10,width='100%',height='100%')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

locations = []
for lat, long in zip(df['origin_latitude'], df["origin_longitude"]):
    location = (lat, long)
    locations.append(location)

locations
# Out:
# [(51.456173, -0.978916),
#  (51.456843, -0.950385),
#  (51.456843, -0.950385),
#  (51.456843, -0.950385),
#  (51.455544, -0.96952),
#  (51.455544, -0.96952),
#  (51.455544, -0.96952),
#  (51.455544, -0.96952),
#  (51.455544, -0.96952),
#  (51.455544, -0.96952),
#  (51.460544, -1.054671),
#  (51.460544, -1.054671),
#  (51.460544, -1.054671),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.45638, -0.947011),
#  (51.470372, -0.955637),
#  (51.470372, -0.955637),
#  (51.470372, -0.955637),
#  (51.470372, -0.955637),
#  (51.470372, -0.955637),
#  (51.470372, -0.955637),
#  (51.454308, -1.052298),
#  (51.454308, -1.052298),
#  (51.454308, -1.052298),
#  (51.454308, -1.052298),
#  (51.454308, -1.052298),
#  (51.433202, -0.976216),
#  (51.447065, -0.93467),
#  (51.447065, -0.93467),
#  (51.447065, -0.93467),
# ...

# %%
from folium import plugins
plugins.MarkerCluster(locations).add_to(m)
m
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from folium import plugins

plugins.HeatMap(locations).add_to(m)
m
# Out:
# Output hidden; open in https://colab.research.google.com to view.
